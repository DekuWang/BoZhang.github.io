# %%
import pandas
import numpy

# %%
steam_data = pandas.read_csv("steam-200k.xlsm")

steam_data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6480/2305897417.py in <module>
# ----> 1 steam_data = pandas.read_csv("steam-200k.xlsm")
#       2
#       3 steam_data.head()
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
steam_data.value_counts()
# Out:
# url                                                                types  name                     desc_snippet                                                                                                                                                                                                                                                                                               recent_reviews                                                                           all_reviews                                                                            release_date  developer                              publisher                                  popular_tags                                                                                                                                                                                                                          game_details                                                                                      
# ...
